# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append("/content/drive/My Drive/DICAM_ReTrain")
# sys.path.append("/content/drive/My Drive/UColor_ReTrain")

# %%
import os
# 改变当前工作目录到谷歌云盘的路径
path="/content/drive/My Drive/DICAM_ReTrain"
os.chdir(path)
os.listdir(path)
# Out:
# ['README.md',
#  'LICENSE',
#  'requirements.txt',
#  'uiqm.py',
#  'hist_distance.m',
#  'evaluation.py',
#  'histogram distance functions',
#  'EUVP',
#  'results',
#  'UIEB',
#  '__pycache__',
#  'Data',
#  '.history',
#  'ckpts_PreTrain',
#  'ckpts_ReTrain',
#  '.ipynb_checkpoints',
#  'HowToUse.txt']

# %%
cd /content/drive/My Drive/DICAM_ReTrain
# Out:
# /content/drive/My Drive/DICAM_ReTrain

# %%
import glob
# 定义两个文件夹路径
raw_dir = os.path.join(path, "raw-60-gc")
reference_dir = os.path.join(path, "reference-60")

# 获取raw-2235文件夹中的所有文件名（不含路径）
raw_files = set(os.path.basename(f) for f in glob.glob(os.path.join(raw_dir, '*.*')))

# 获取reference-2235文件夹中的所有文件名（不含路径）
reference_files = set(os.path.basename(f) for f in glob.glob(os.path.join(reference_dir, '*.*')))

# 找出存在于reference-2235中但不存在于raw-2235中的文件
files_to_delete = reference_files - raw_files

print(files_to_delete)
# Out:
# set()

# %%
pip install pytorch-msssim
# Out:
# Collecting pytorch-msssim
#   Downloading pytorch_msssim-1.0.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from pytorch-msssim) (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->pytorch-msssim) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->pytorch-msssim) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->pytorch-msssim) (1.3.0)
# Downloading pytorch_msssim-1.0.0-py3-none-any.whl (7.7 kB)
# Installing collected packages: pytorch-msssim
# Successfully installed pytorch-msssim-1.0.0

# %%
# !python ./UIEB/train_uieb.py
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 256, 256]             128
#          LeakyReLU-2         [-1, 64, 256, 256]               0
#             Conv2d-3         [-1, 64, 256, 256]          36,928
#          LeakyReLU-4         [-1, 64, 256, 256]               0
#             Conv2d-5         [-1, 64, 256, 256]             128
#          LeakyReLU-6         [-1, 64, 256, 256]               0
#             Conv2d-7         [-1, 64, 256, 256]         102,464
#          LeakyReLU-8         [-1, 64, 256, 256]               0
#          MaxPool2d-9          [-1, 1, 256, 256]               0
#            Conv2d-10         [-1, 64, 256, 256]             128
#         LeakyReLU-11         [-1, 64, 256, 256]               0
#            Conv2d-12         [-1, 64, 256, 256]             128
#         LeakyReLU-13         [-1, 64, 256, 256]               0
#               Inc-14        [-1, 256, 256, 256]               0
#            Conv2d-15         [-1, 64, 256, 256]             128
#         LeakyReLU-16         [-1, 64, 256, 256]               0
#            Conv2d-17         [-1, 64, 256, 256]          36,928
#         LeakyReLU-18         [-1, 64, 256, 256]               0
#            Conv2d-19         [-1, 64, 256, 256]             128
#         LeakyReLU-20         [-1, 64, 256, 256]               0
#            Conv2d-21         [-1, 64, 256, 256]         102,464
#         LeakyReLU-22         [-1, 64, 256, 256]               0
#         MaxPool2d-23          [-1, 1, 256, 256]               0
#            Conv2d-24         [-1, 64, 256, 256]             128
#         LeakyReLU-25         [-1, 64, 256, 256]               0
#            Conv2d-26         [-1, 64, 256, 256]             128
#         LeakyReLU-27         [-1, 64, 256, 256]               0
#               Inc-28        [-1, 256, 256, 256]               0
#            Conv2d-29         [-1, 64, 256, 256]             128
#         LeakyReLU-30         [-1, 64, 256, 256]               0
#            Conv2d-31         [-1, 64, 256, 256]          36,928
#         LeakyReLU-32         [-1, 64, 256, 256]               0
#            Conv2d-33         [-1, 64, 256, 256]             128
#         LeakyReLU-34         [-1, 64, 256, 256]               0
#            Conv2d-35         [-1, 64, 256, 256]         102,464
#         LeakyReLU-36         [-1, 64, 256, 256]               0
#         MaxPool2d-37          [-1, 1, 256, 256]               0
#            Conv2d-38         [-1, 64, 256, 256]             128
#         LeakyReLU-39         [-1, 64, 256, 256]               0
#            Conv2d-40         [-1, 64, 256, 256]             128
#         LeakyReLU-41         [-1, 64, 256, 256]               0
#               Inc-42        [-1, 256, 256, 256]               0
# AdaptiveAvgPool2d-43            [-1, 256, 1, 1]               0
#           Flatten-44                  [-1, 256]               0
#            Linear-45                   [-1, 64]          16,448
#          Softsign-46                   [-1, 64]               0
#            Linear-47                  [-1, 256]          16,640
#          Softsign-48                  [-1, 256]               0
#               CAM-49        [-1, 256, 256, 256]               0
# AdaptiveAvgPool2d-50            [-1, 256, 1, 1]               0
#           Flatten-51                  [-1, 256]               0
#            Linear-52                   [-1, 64]          16,448
#          Softsign-53                   [-1, 64]               0
#            Linear-54                  [-1, 256]          16,640
#          Softsign-55                  [-1, 256]               0
#               CAM-56        [-1, 256, 256, 256]               0
# AdaptiveAvgPool2d-57            [-1, 256, 1, 1]               0
#           Flatten-58                  [-1, 256]               0
#            Linear-59                   [-1, 64]          16,448
#          Softsign-60                   [-1, 64]               0
#            Linear-61                  [-1, 256]          16,640
#          Softsign-62                  [-1, 256]               0
#               CAM-63        [-1, 256, 256, 256]               0
#            Conv2d-64         [-1, 64, 256, 256]          49,216
#         LeakyReLU-65         [-1, 64, 256, 256]               0
#            Conv2d-66         [-1, 64, 256, 256]          36,928
#         LeakyReLU-67         [-1, 64, 256, 256]               0
#            Conv2d-68         [-1, 64, 256, 256]          49,216
#         LeakyReLU-69         [-1, 64, 256, 256]               0
#            Conv2d-70         [-1, 64, 256, 256]         102,464
#         LeakyReLU-71         [-1, 64, 256, 256]               0
#         MaxPool2d-72        [-1, 768, 256, 256]               0
#            Conv2d-73         [-1, 64, 256, 256]          49,216
#         LeakyReLU-74         [-1, 64, 256, 256]               0
#            Conv2d-75         [-1, 64, 256, 256]          49,216
#         LeakyReLU-76         [-1, 64, 256, 256]               0
#               Inc-77        [-1, 256, 256, 256]               0
# AdaptiveAvgPool2d-78            [-1, 256, 1, 1]               0
#           Flatten-79                  [-1, 256]               0
#            Linear-80                   [-1, 64]          16,448
#          Softsign-81                   [-1, 64]               0
#            Linear-82                  [-1, 256]          16,640
#          Softsign-83                  [-1, 256]               0
#               CAM-84        [-1, 256, 256, 256]               0
#            Conv2d-85         [-1, 24, 256, 256]          55,320
#         LeakyReLU-86         [-1, 24, 256, 256]               0
#            Conv2d-87          [-1, 3, 256, 256]              75
#           Sigmoid-88          [-1, 3, 256, 256]               0
# ================================================================
# Total params: 943,715
# Trainable params: 943,715
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 2972.54
# Params size (MB): 3.60
# Estimated Total Size (MB): 2976.89
# ----------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# loading model for DICAM  None
# No checkpoints found for DICAM retraining
#  Epoch : 1 | (156/156) | l_mae: 0.04288733750581741 | l_ssim: 0.8851355910301208 | l_vgg: 0.4758591651916504
#
# Finished ep. 1, lr = 0.010000, mean_mae = 0.063798, mean_ssim = 0.729408, mean_vgg = 0.655274
#  Epoch : 2 | (156/156) | l_mae: 0.03796420246362686 | l_ssim: 0.8770660161972046 | l_vgg: 0.5825021862983704
#
# Finished ep. 2, lr = 0.010000, mean_mae = 0.045751, mean_ssim = 0.853920, mean_vgg = 0.497183
#  Epoch : 3 | (156/156) | l_mae: 0.03070046193897724 | l_ssim: 0.8979589343070984 | l_vgg: 0.40840306878089905
#
# Finished ep. 3, lr = 0.010000, mean_mae = 0.042875, mean_ssim = 0.867143, mean_vgg = 0.472466
#  Epoch : 4 | (156/156) | l_mae: 0.04645790159702301 | l_ssim: 0.8811073303222656 | l_vgg: 0.44431909918785095
#
# Finished ep. 4, lr = 0.010000, mean_mae = 0.041219, mean_ssim = 0.878773, mean_vgg = 0.442994
#  Epoch : 5 | (156/156) | l_mae: 0.04389847442507744 | l_ssim: 0.9099115133285522 | l_vgg: 0.4536205232143402
#
# Finished ep. 5, lr = 0.010000, mean_mae = 0.039313, mean_ssim = 0.886283, mean_vgg = 0.430230
#  Epoch : 6 | (156/156) | l_mae: 0.031280819326639175 | l_ssim: 0.8871511816978455 | l_vgg: 0.3556611239910126
#
# Finished ep. 6, lr = 0.010000, mean_mae = 0.038715, mean_ssim = 0.887727, mean_vgg = 0.427519
#  Epoch : 7 | (156/156) | l_mae: 0.04643448069691658 | l_ssim: 0.8588227033615112 | l_vgg: 0.5930089950561523
#
# Finished ep. 7, lr = 0.010000, mean_mae = 0.038420, mean_ssim = 0.890206, mean_vgg = 0.419269
#  Epoch : 8 | (156/156) | l_mae: 0.033002521842718124 | l_ssim: 0.9221521615982056 | l_vgg: 0.35430383682250977
#
# Finished ep. 8, lr = 0.010000, mean_mae = 0.038698, mean_ssim = 0.889985, mean_vgg = 0.421835
#  Epoch : 9 | (156/156) | l_mae: 0.043247926980257034 | l_ssim: 0.830046534538269 | l_vgg: 0.4926687180995941
#
# Finished ep. 9, lr = 0.010000, mean_mae = 0.038616, mean_ssim = 0.890148, mean_vgg = 0.424323
#  Epoch : 10 | (156/156) | l_mae: 0.02893432043492794 | l_ssim: 0.9334883093833923 | l_vgg: 0.3701314628124237
#
# Finished ep. 10, lr = 0.010000, mean_mae = 0.038174, mean_ssim = 0.891060, mean_vgg = 0.417901
#  Epoch : 11 | (156/156) | l_mae: 0.032151490449905396 | l_ssim: 0.892240583896637 | l_vgg: 0.45799383521080017
#
# Finished ep. 11, lr = 0.010000, mean_mae = 0.037989, mean_ssim = 0.891781, mean_vgg = 0.417659
#  Epoch : 12 | (156/156) | l_mae: 0.02512333355844021 | l_ssim: 0.9233211874961853 | l_vgg: 0.35846659541130066
#
# Finished ep. 12, lr = 0.010000, mean_mae = 0.037929, mean_ssim = 0.892087, mean_vgg = 0.416454
#  Epoch : 13 | (156/156) | l_mae: 0.041765764355659485 | l_ssim: 0.863508403301239 | l_vgg: 0.4497353732585907
#
# Finished ep. 13, lr = 0.010000, mean_mae = 0.037932, mean_ssim = 0.892137, mean_vgg = 0.413103
#  Epoch : 14 | (156/156) | l_mae: 0.04693743586540222 | l_ssim: 0.8811590075492859 | l_vgg: 0.4430549740791321
#
# Finished ep. 14, lr = 0.010000, mean_mae = 0.036981, mean_ssim = 0.896696, mean_vgg = 0.408706
#  Epoch : 15 | (156/156) | l_mae: 0.043409571051597595 | l_ssim: 0.8606531023979187 | l_vgg: 0.47755908966064453
#
# Finished ep. 15, lr = 0.010000, mean_mae = 0.036557, mean_ssim = 0.896683, mean_vgg = 0.403038
#  Epoch : 16 | (156/156) | l_mae: 0.049680937081575394 | l_ssim: 0.84796541929245 | l_vgg: 0.43559199571609497
#
# Finished ep. 16, lr = 0.010000, mean_mae = 0.036710, mean_ssim = 0.896551, mean_vgg = 0.407438
#  Epoch : 17 | (156/156) | l_mae: 0.035937659442424774 | l_ssim: 0.9243270754814148 | l_vgg: 0.3613513112068176
#
# Finished ep. 17, lr = 0.010000, mean_mae = 0.036747, mean_ssim = 0.896992, mean_vgg = 0.404568
#  Epoch : 18 | (156/156) | l_mae: 0.030862420797348022 | l_ssim: 0.9206452965736389 | l_vgg: 0.4011019766330719
#
# Finished ep. 18, lr = 0.010000, mean_mae = 0.035626, mean_ssim = 0.899484, mean_vgg = 0.398269
#  Epoch : 19 | (156/156) | l_mae: 0.038421861827373505 | l_ssim: 0.8845385909080505 | l_vgg: 0.41946712136268616
#
# Finished ep. 19, lr = 0.010000, mean_mae = 0.036568, mean_ssim = 0.896398, mean_vgg = 0.407107
#  Epoch : 20 | (156/156) | l_mae: 0.03126852586865425 | l_ssim: 0.921434223651886 | l_vgg: 0.43223974108695984
#
# Finished ep. 20, lr = 0.010000, mean_mae = 0.035846, mean_ssim = 0.899170, mean_vgg = 0.399853
#  Epoch : 21 | (156/156) | l_mae: 0.04606800153851509 | l_ssim: 0.9181320667266846 | l_vgg: 0.35666829347610474
#
# Finished ep. 21, lr = 0.010000, mean_mae = 0.036741, mean_ssim = 0.898153, mean_vgg = 0.399352
#  Epoch : 22 | (156/156) | l_mae: 0.034333549439907074 | l_ssim: 0.9025668501853943 | l_vgg: 0.42566171288490295
#
# Finished ep. 22, lr = 0.010000, mean_mae = 0.036122, mean_ssim = 0.898296, mean_vgg = 0.400495
#  Epoch : 23 | (156/156) | l_mae: 0.03847581520676613 | l_ssim: 0.8677780032157898 | l_vgg: 0.4168909192085266
#
# Finished ep. 23, lr = 0.010000, mean_mae = 0.035999, mean_ssim = 0.899794, mean_vgg = 0.398833
#  Epoch : 24 | (156/156) | l_mae: 0.03224777430295944 | l_ssim: 0.9024639129638672 | l_vgg: 0.42200228571891785
#
# Finished ep. 24, lr = 0.010000, mean_mae = 0.036042, mean_ssim = 0.898629, mean_vgg = 0.400521
#  Epoch : 25 | (156/156) | l_mae: 0.029443640261888504 | l_ssim: 0.9205568432807922 | l_vgg: 0.35573267936706543
#
# Finished ep. 25, lr = 0.010000, mean_mae = 0.035698, mean_ssim = 0.900574, mean_vgg = 0.397857
#  Epoch : 26 | (156/156) | l_mae: 0.03363625332713127 | l_ssim: 0.8687382340431213 | l_vgg: 0.45267772674560547
#
# Finished ep. 26, lr = 0.010000, mean_mae = 0.035575, mean_ssim = 0.901471, mean_vgg = 0.392793
#  Epoch : 27 | (156/156) | l_mae: 0.025878731161355972 | l_ssim: 0.9426727890968323 | l_vgg: 0.3647017776966095
#
# Finished ep. 27, lr = 0.010000, mean_mae = 0.035141, mean_ssim = 0.901392, mean_vgg = 0.393154
#  Epoch : 28 | (156/156) | l_mae: 0.04585038125514984 | l_ssim: 0.8762735724449158 | l_vgg: 0.37466904520988464
#
# Finished ep. 28, lr = 0.010000, mean_mae = 0.035019, mean_ssim = 0.902963, mean_vgg = 0.391580
#  Epoch : 29 | (156/156) | l_mae: 0.03665619716048241 | l_ssim: 0.9153180718421936 | l_vgg: 0.3916415870189667
#
# Finished ep. 29, lr = 0.010000, mean_mae = 0.035812, mean_ssim = 0.900828, mean_vgg = 0.391633
#  Epoch : 30 | (156/156) | l_mae: 0.03907035291194916 | l_ssim: 0.8551102876663208 | l_vgg: 0.443004846572876
#
# Finished ep. 30, lr = 0.010000, mean_mae = 0.035872, mean_ssim = 0.899841, mean_vgg = 0.394712
#  Epoch : 31 | (156/156) | l_mae: 0.038595035672187805 | l_ssim: 0.9117283821105957 | l_vgg: 0.3304051160812378
#
# Finished ep. 31, lr = 0.010000, mean_mae = 0.035508, mean_ssim = 0.902065, mean_vgg = 0.390356
#  Epoch : 32 | (156/156) | l_mae: 0.034999698400497437 | l_ssim: 0.9123951196670532 | l_vgg: 0.3574105501174927
#
# Finished ep. 32, lr = 0.010000, mean_mae = 0.035977, mean_ssim = 0.898817, mean_vgg = 0.402670
#  Epoch : 33 | (156/156) | l_mae: 0.03684531897306442 | l_ssim: 0.8949233293533325 | l_vgg: 0.530637264251709
#
# Finished ep. 33, lr = 0.010000, mean_mae = 0.034979, mean_ssim = 0.903067, mean_vgg = 0.394338
#  Epoch : 34 | (156/156) | l_mae: 0.038208335638046265 | l_ssim: 0.9283818006515503 | l_vgg: 0.3341112732887268
#
# Finished ep. 34, lr = 0.010000, mean_mae = 0.035097, mean_ssim = 0.901774, mean_vgg = 0.394669
#  Epoch : 35 | (156/156) | l_mae: 0.022487495094537735 | l_ssim: 0.9007704854011536 | l_vgg: 0.3682127892971039
#
# Finished ep. 35, lr = 0.010000, mean_mae = 0.035586, mean_ssim = 0.901665, mean_vgg = 0.393475
#  Epoch : 36 | (156/156) | l_mae: 0.02904614806175232 | l_ssim: 0.9641628861427307 | l_vgg: 0.3209463059902191
#
# Finished ep. 36, lr = 0.010000, mean_mae = 0.035466, mean_ssim = 0.901044, mean_vgg = 0.397450
#  Epoch : 37 | (156/156) | l_mae: 0.02423161454498768 | l_ssim: 0.9469736814498901 | l_vgg: 0.2940748333930969
#
# Finished ep. 37, lr = 0.010000, mean_mae = 0.034860, mean_ssim = 0.904135, mean_vgg = 0.386719
#  Epoch : 38 | (156/156) | l_mae: 0.023624399676918983 | l_ssim: 0.9460716843605042 | l_vgg: 0.400580495595932
#
# Finished ep. 38, lr = 0.010000, mean_mae = 0.035026, mean_ssim = 0.902048, mean_vgg = 0.392345
#  Epoch : 39 | (156/156) | l_mae: 0.03165620192885399 | l_ssim: 0.9348818063735962 | l_vgg: 0.3332221210002899
#
# Finished ep. 39, lr = 0.010000, mean_mae = 0.034833, mean_ssim = 0.903037, mean_vgg = 0.388669
#  Epoch : 40 | (156/156) | l_mae: 0.03606454282999039 | l_ssim: 0.8509674668312073 | l_vgg: 0.5115103125572205
#
# Finished ep. 40, lr = 0.010000, mean_mae = 0.034762, mean_ssim = 0.902997, mean_vgg = 0.388314
#  Epoch : 41 | (156/156) | l_mae: 0.035562239587306976 | l_ssim: 0.8715953230857849 | l_vgg: 0.44066235423088074
#
# Finished ep. 41, lr = 0.010000, mean_mae = 0.034819, mean_ssim = 0.903250, mean_vgg = 0.388169
#  Epoch : 42 | (156/156) | l_mae: 0.040706194937229156 | l_ssim: 0.8776524066925049 | l_vgg: 0.4769640862941742
#
# Finished ep. 42, lr = 0.010000, mean_mae = 0.034894, mean_ssim = 0.904189, mean_vgg = 0.386459
#  Epoch : 43 | (156/156) | l_mae: 0.027333466336131096 | l_ssim: 0.9352049827575684 | l_vgg: 0.3248937129974365
#
# Finished ep. 43, lr = 0.010000, mean_mae = 0.034549, mean_ssim = 0.904098, mean_vgg = 0.386002
#  Epoch : 44 | (156/156) | l_mae: 0.03315344080328941 | l_ssim: 0.90762859582901 | l_vgg: 0.3935750722885132
#
# Finished ep. 44, lr = 0.010000, mean_mae = 0.035371, mean_ssim = 0.903062, mean_vgg = 0.391366
#  Epoch : 45 | (156/156) | l_mae: 0.03179110959172249 | l_ssim: 0.909026026725769 | l_vgg: 0.48182040452957153
#
# Finished ep. 45, lr = 0.010000, mean_mae = 0.033921, mean_ssim = 0.906066, mean_vgg = 0.382976
#  Epoch : 46 | (156/156) | l_mae: 0.03704744204878807 | l_ssim: 0.8622022271156311 | l_vgg: 0.4110383093357086
#
# Finished ep. 46, lr = 0.010000, mean_mae = 0.034818, mean_ssim = 0.903196, mean_vgg = 0.388134
#  Epoch : 47 | (156/156) | l_mae: 0.039081256836652756 | l_ssim: 0.887173056602478 | l_vgg: 0.4446309208869934
#
# Finished ep. 47, lr = 0.010000, mean_mae = 0.034620, mean_ssim = 0.903498, mean_vgg = 0.385913
#  Epoch : 48 | (156/156) | l_mae: 0.03743594512343407 | l_ssim: 0.8930477499961853 | l_vgg: 0.4188091456890106
#
# Finished ep. 48, lr = 0.010000, mean_mae = 0.034348, mean_ssim = 0.905198, mean_vgg = 0.385641
#  Epoch : 49 | (156/156) | l_mae: 0.029143840074539185 | l_ssim: 0.949180006980896 | l_vgg: 0.3650370240211487
#
# Finished ep. 49, lr = 0.010000, mean_mae = 0.034692, mean_ssim = 0.905416, mean_vgg = 0.384025
#  Epoch : 50 | (156/156) | l_mae: 0.03913804888725281 | l_ssim: 0.813502848148346 | l_vgg: 0.46670103073120117
#
# Finished ep. 50, lr = 0.010000, mean_mae = 0.034638, mean_ssim = 0.903885, mean_vgg = 0.384294
#  Epoch : 51 | (156/156) | l_mae: 0.04304566606879234 | l_ssim: 0.8641952276229858 | l_vgg: 0.4061354696750641
#
# Finished ep. 51, lr = 0.010000, mean_mae = 0.034436, mean_ssim = 0.905240, mean_vgg = 0.385136
#  Epoch : 52 | (156/156) | l_mae: 0.027170922607183456 | l_ssim: 0.9294319748878479 | l_vgg: 0.35183706879615784
#
# Finished ep. 52, lr = 0.010000, mean_mae = 0.034282, mean_ssim = 0.904612, mean_vgg = 0.384573
#  Epoch : 53 | (156/156) | l_mae: 0.037327203899621964 | l_ssim: 0.8878448605537415 | l_vgg: 0.41363152861595154
#
# Finished ep. 53, lr = 0.010000, mean_mae = 0.035034, mean_ssim = 0.903578, mean_vgg = 0.385068
#  Epoch : 54 | (156/156) | l_mae: 0.02149602212011814 | l_ssim: 0.9475668668746948 | l_vgg: 0.2782406508922577
#
# Finished ep. 54, lr = 0.010000, mean_mae = 0.034887, mean_ssim = 0.903976, mean_vgg = 0.384962
#  Epoch : 55 | (156/156) | l_mae: 0.036920033395290375 | l_ssim: 0.8914019465446472 | l_vgg: 0.44857531785964966
#
# Finished ep. 55, lr = 0.010000, mean_mae = 0.034950, mean_ssim = 0.904738, mean_vgg = 0.383193
#  Epoch : 56 | (156/156) | l_mae: 0.03593061491847038 | l_ssim: 0.9452057480812073 | l_vgg: 0.37945327162742615
#
# Finished ep. 56, lr = 0.010000, mean_mae = 0.034038, mean_ssim = 0.905511, mean_vgg = 0.385758
#  Epoch : 57 | (156/156) | l_mae: 0.04130575805902481 | l_ssim: 0.8576752543449402 | l_vgg: 0.40221938490867615
#
# Finished ep. 57, lr = 0.010000, mean_mae = 0.034598, mean_ssim = 0.904028, mean_vgg = 0.386713
#  Epoch : 58 | (156/156) | l_mae: 0.027774715796113014 | l_ssim: 0.8969753980636597 | l_vgg: 0.36552080512046814
#
# Finished ep. 58, lr = 0.010000, mean_mae = 0.033761, mean_ssim = 0.905921, mean_vgg = 0.385583
#  Epoch : 59 | (156/156) | l_mae: 0.033119093626737595 | l_ssim: 0.9189262986183167 | l_vgg: 0.3767153024673462
#
# Finished ep. 59, lr = 0.010000, mean_mae = 0.034294, mean_ssim = 0.905399, mean_vgg = 0.384402
#  Epoch : 60 | (156/156) | l_mae: 0.039673496037721634 | l_ssim: 0.895283579826355 | l_vgg: 0.40943393111228943
#
# Finished ep. 60, lr = 0.010000, mean_mae = 0.033901, mean_ssim = 0.905231, mean_vgg = 0.384637

# %%
# 修改options.py中的"--testing_dir_inp"参数后测试，生成图像在test.uieb.py中的result_dir = 'Data/Test_Res/'中
# !python ./UIEB/test_uieb.py
# Out:
# /content/drive/MyDrive/DICAM_ReTrain/./UIEB/test_uieb.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(os.path.join(CHECKPOINTS_DIR,"DICAM_60.pt"),map_location=torch.device('cpu'))
#   0% 0/2 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/DICAM_ReTrain/./UIEB/test_uieb.py", line 51, in <module>
#     img = img[:, :, ::-1]
# TypeError: 'NoneType' object is not subscriptable
