# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append("/content/drive/My Drive/UColor")
# sys.path.append("/content/drive/My Drive/UColor_ReTrain")

# %%
import os
# 改变当前工作目录到谷歌云盘的路径
path="/content/drive/My Drive/UColor"
os.chdir(path)
os.listdir(path)
# Out:
# ['vgg.py',
#  'rgb_lab_formulation.py',
#  'ssim.py',
#  'vgg_pretrained',
#  'raw-780',
#  'reference-780',
#  'raw-60',
#  'reference-60',
#  'GDCP',
#  'Test-Ucolor',
#  'checkpoint',
#  '__pycache__',
#  'sample',
#  'model_test.py',
#  'main_test.py',
#  'checkpoint_UColor-ReTrain',
#  'sample_UColor-ReTrain',
#  'middle_save_enhance_UColor-ReTrain',
#  'val_save_enhance__UColor-ReTrain',
#  'checkpoint_best_UColor-ReTrain',
#  'ops.py',
#  'wandb',
#  'main_train.py',
#  'model_train.py',
#  'utils.py']

# %%
cd /content/drive/My Drive/UColor
# Out:
# /content/drive/My Drive/UColor

# %%
import glob
# 定义两个文件夹路径
raw_dir = os.path.join(path, "./GDCP/GDCP-60")
reference_dir = os.path.join(path, "reference-60")

# 获取raw-2235文件夹中的所有文件名（不含路径）
raw_files = set(os.path.basename(f) for f in glob.glob(os.path.join(raw_dir, '*.*')))

# 获取reference-2235文件夹中的所有文件名（不含路径）
reference_files = set(os.path.basename(f) for f in glob.glob(os.path.join(reference_dir, '*.*')))

# 找出存在于reference-2235中但不存在于raw-2235中的文件
files_to_delete = reference_files - raw_files

print(files_to_delete)
# Out:
# set()

# %%
pip install wandb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 109.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 19.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.8/313.8 kB 28.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.2 MB/s eta 0:00:00
# ...

# %%
# !pip install tensorflow==1.15
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==1.15 (from versions: 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.11.1, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.0.post1, 2.15.1, 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.18.0rc0, 2.18.0rc1)
# ERROR: No matching distribution found for tensorflow==1.15

# %%
# !python main_train.py
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# start  8  in ep  3  with total  48
# Epoch: [ 4], step: [153], time: [1475.3126],mse_loss: [0.09464781],vgg_loss: [0.50921983],final_loss: [0.60386765]
# /content/drive/MyDrive/UColor/model_train.py:286: UserWarning: middle_save_enhance_UColor-ReTrain/136_enhance_io.png is a low contrast image
#   io.imsave(save_path_en_io, final_enhanced_img_out)
# start  9  in ep  3  with total  48
# Epoch: [ 4], step: [154], time: [1478.9291],mse_loss: [0.10712571],vgg_loss: [0.73377299],final_loss: [0.84089869]
# start  10  in ep  3  with total  48
# Epoch: [ 4], step: [155], time: [1482.7682],mse_loss: [0.11110473],vgg_loss: [0.37605032],final_loss: [0.48715505]
# /content/drive/MyDrive/UColor/model_train.py:286: UserWarning: middle_save_enhance_UColor-ReTrain/162_enhance_io.png is a low contrast image
#   io.imsave(save_path_en_io, final_enhanced_img_out)
# ...

# %%
# 修改options.py中的"--testing_dir_inp"参数后测试，生成图像在test.uieb.py中的result_dir = 'Data/Test_Res/'中
# !python main_test.py
# Out:
# 2024-10-15 08:51:36.310604: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-15 08:51:36.329003: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-15 08:51:36.350592: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-15 08:51:36.357084: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
