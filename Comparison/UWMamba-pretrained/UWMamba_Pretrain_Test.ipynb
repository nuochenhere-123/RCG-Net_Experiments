# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append("/content/drive/My Drive/UWMamba-main")
# sys.path.append("/content/drive/My Drive/UColor_ReTrain")

# %%
import os
# 改变当前工作目录到谷歌云盘的路径
path="/content/drive/My Drive/UWMamba-main"
os.chdir(path)
os.listdir(path)
# Out:
# ['pyproject.toml',
#  '__init__.py',
#  'tool',
#  '.idea',
#  'output',
#  'test',
#  'experiments',
#  'pretrained_models',
#  'data',
#  'lib',
#  'mamba_ssm',
#  'setup.py',
#  'build',
#  'mamba_ssm.egg-info',
#  'csrc',
#  'log',
#  '.ipynb_checkpoints',
#  'README_of_UWMamba.md',
#  'eval_enh.py']

# %%
cd /content/drive/My Drive/UWMamba-main
# Out:
# /content/drive/My Drive/UWMamba-main

# %%
# !pip install --no-binary :all: mamba_ssm
# !pip install --no-build-isolation .
# Out:
# ...
#   Using cached mamba_ssm-2.2.2.tar.gz (85 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for mamba_ssm
#   Running setup.py clean for mamba_ssm
# Failed to build mamba_ssm
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (mamba_ssm)

# %%
# !pip install triton yacs kornia
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.4/899.4 kB 55.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 79.8 MB/s eta 0:00:00
# ...

# %%
# !python eval_enh.py
